# %% [markdown]
# ### SparQL

# %% [markdown]
# ### Linking Items in Wiki

# %%
import pandas as pd
import json
import requests
from SPARQLWrapper import SPARQLWrapper, JSON,POST
import time
from tqdm import tqdm

# %%
# 259 Modalities
json_file = 'updated_modalities.json' 
with open(json_file, 'r') as file:
    data = json.load(file)

modalities = data.get('updated modalities', [])
modality_df = pd.DataFrame(modalities, columns=['modality'])

modality_df['lower_modality'] = modality_df['modality'].str.lower() 
modality_df = modality_df.drop_duplicates(subset='lower_modality').drop(columns='lower_modality')

modality_df = modality_df.sort_values(by='modality').reset_index(drop=True)

print(modality_df)
# Out:
#           modality
# 0               2d
# 1         2d image
# 2     2d structure
# 3               3d
# 4    3d annotation
# ..             ...
# 254  visualization
# 255             vr
# 256            web
# 257  web structure
# 258       wireless
#
# [259 rows x 1 columns]

# %%
# save to CSV
modality_df.to_csv('modality_259.csv', sep=',', index=True, header=True)

# %%
words = modality_df['modality'].tolist()

# %%
# get QID from Wikidata Search API
def get_qid(word):
    url = f"https://www.wikidata.org/w/api.php?action=wbsearchentities&search={word}&language=en&format=json&limit=1"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['search']:
            return data['search'][0]['id']  # QID (e.g., 'Q42')
    return None

# %%
# Get QID from Wikidata Search API with exact matching
def get_qid_exact(word):
    url = f"https://www.wikidata.org/w/api.php?action=wbsearchentities&search={word}&language=en&format=json&limit=20"  # Get multiple results
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        
        if data['search']:
            for result in data['search']:
                # Check for exact match on the label
                if result['label'].lower() == word.lower():  # Case-insensitive comparison
                    return result['id']  # QID 
    return None

# %%
# Map words to QIDs
qid_mapping = {}

for word in tqdm(words, desc="Mapping words to QIDs"):
    qid = get_qid(word)
    if qid:
        qid_mapping[word] = qid
    else:
        qid_mapping[word] = None
    time.sleep(0.1)  # To avoid overloading the API
# Out:
# Mapping words to QIDs: 100%|██████████| 259/259 [01:37<00:00,  2.65it/s]

# %%
none_count = sum(1 for qid in qid_mapping.values() if qid is None)
total_count = len(qid_mapping)
none_percentage = (none_count / total_count) * 100

print(f"Words with None QID: {none_count}")
print(f"Percentage of None QID mappings: {none_percentage:.2f}%")
# Out:
# Words with None QID: 16
# Percentage of None QID mappings: 6.18%

# %%
# Map exact words to QIDs
qid_mapping_exact = {}

for word in tqdm(words, desc="Mapping words to QIDs"):
    qid = get_qid_exact(word)
    if qid:
        qid_mapping_exact[word] = qid
    else:
        qid_mapping_exact[word] = None
    time.sleep(0.1)  # To avoid overloading the API
# Out:
# Mapping words to QIDs: 100%|██████████| 259/259 [01:43<00:00,  2.50it/s]

# %%
# exact word ratio
none_count = sum(1 for qid in qid_mapping_exact.values() if qid is None)
total_count = len(qid_mapping_exact)
none_percentage = (none_count / total_count) * 100

print(f"Words with None QID: {none_count}")
print(f"Percentage of None QID mappings: {none_percentage:.2f}%")
# Out:
# Words with None QID: 105
# Percentage of None QID mappings: 40.54%

# %%
import csv

no_qid_words = {word: qid for word, qid in qid_mapping_exact.items() if qid is None}
has_qid_words = {word: qid for word, qid in qid_mapping_exact.items() if qid is not None}

with open('words_no_qid.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['word', 'qid'])  
    for word, qid in no_qid_words.items():
        writer.writerow([word, qid])

with open('words_with_qid.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['word', 'qid'])  
    for word, qid in has_qid_words.items():
        writer.writerow([word, qid])

# %%
qid_mapping_exact
# Out:
# {'2d': 'Q5651824',
#  '2d image': None,
#  '2d structure': None,
#  '3d': 'Q108276326',
#  '3d annotation': None,
#  '3d body skeleton': None,
#  '3d coordinate': None,
#  '3d environment': None,
#  '3d landmark': None,
#  '3d layout': None,
#  '3d lidar': None,
#  '3d mesh': None,
#  '3d model': 'Q3859833',
#  '3d model parameter': None,
#  '3d motion': None,
#  '3d motion capture': None,
#  '3d object': None,
#  '3d point': None,
#  '3d point cloud': None,
#  '3d pose': None,
#  '3d pose annotation': None,
#  '3d scalar field': None,
#  '3d scan': None,
#  '3d simulation': None,
#  '3d skeletal': None,
#  '3d skeleton': None,
#  '3d structure': None,
#  '3d trajectory': None,
#  '4d': 'Q20685814',
#  'action': 'Q2634111',
#  'activity': 'Q1914636',
#  'algorithm': 'Q8366',
#  'alpha matte': None,
#  'analytic': 'Q65311416',
#  'anatomical': None,
#  'animation': 'Q11425',
#  'annotation': 'Q857525',
#  'application': 'Q166142',
#  'audio': 'Q3500685',
#  'audiovisual': 'Q758901',
#  'behavioral': None,
#  'binary': 'Q4913864',
#  'bioassay data': None,
#  'biochemical': 'Q124892534',
#  'biological': None,
#  'biomarker': 'Q864574',
#  'biometric': None,
#  'biosample': 'Q96797376',
#  'biosignal': 'Q644240',
#  'blockchain': 'Q20514253',
#  'body motion': None,
#  'bounding box': None,
#  'box': 'Q16860308',
#  'brain signal': None,
#  'calibration': 'Q736777',
#  'camera': 'Q15328',
#  'camera parameter': None,
#  'camera pose': None,
#  'categorical': None,
#  'chemical': None,
#  'chemical structure': 'Q500256',
#  'code': 'Q37141227',
#  'configuration': 'Q1866689',
#  'container': 'Q1643805',
#  'control': 'Q338754',
#  'control stream': None,
#  'cwl': None,
#  'data': 'Q42848',
#  'data array': None,
#  'data file': 'Q5227290',
#  'data stream': 'Q1172540',
#  'database': 'Q8513',
#  'demographic': None,
#  'depth': 'Q930412',
#  'depth map': 'Q2940499',
#  'document': 'Q49848',
#  'drive': 'Q125338722',
#  'dynamical': None,
#  'ecg': None,
#  'edge map': None,
#  'eeg': 'Q30643862',
#  'electromyography': 'Q27710763',
#  'electrophysiological': None,
#  'embedding': 'Q980509',
#  'emotion': 'Q5373749',
#  'environment': 'Q2249676',
#  'environmental condition': 'Q110792565',
#  'eog': None,
#  'epigenetic': None,
#  'evaluation metric': None,
#  'event': 'Q1656682',
#  'event stream': 'Q104622942',
#  'external tool': None,
#  'eye gaze': None,
#  'eye tracking': 'Q970687',
#  'feature': 'Q814254',
#  'feature vector': 'Q1921842',
#  'file': 'Q193142',
#  'fmri': 'Q18615495',
#  'game': 'Q11410',
#  'gameplay': 'Q1331296',
#  'gaze': 'Q16870142',
#  'genetic': None,
#  'genomic': None,
#  'genomic sequence': None,
#  'geo information': None,
#  'geographical': None,
#  'geolocation': 'Q123349905',
#  'geometry': 'Q8087',
#  'geospatial': 'Q122074678',
#  'gesture': 'Q371174',
#  'gnss': None,
#  'gnss/ins': None,
#  'gps': 'Q368785',
#  'graph': 'Q98669280',
#  'ground truth': 'Q370766',
#  'grounding': 'Q14920473',
#  'haptic': 'Q119732988',
#  'identifier': 'Q853614',
#  'image': 'Q478798',
#  'imu': 'Q26203674',
#  'index': 'Q873506',
#  'inertial': None,
#  'interaction': 'Q4641997',
#  'interaction log': None,
#  'interactive': 'Q1636759',
#  'interactive environment': None,
#  'json': 'Q2063',
#  'key point': 'Q34961254',
#  'kinematic': 'Q25215452',
#  'kinesthetic': None,
#  'knowledge base': 'Q593744',
#  'knowledge graph': 'Q33002955',
#  'label': 'Q722218',
#  'laser scan': None,
#  'lidar': 'Q504027',
#  'link': 'Q63617815',
#  'list': 'Q1828075',
#  'location': 'Q115095765',
#  'log': 'Q39304236',
#  'magnetoencephalography': 'Q384188',
#  'map': 'Q4006',
#  'mask': 'Q161524',
#  'matrix': 'Q44337',
#  'meta information': None,
#  'metadata': 'Q180160',
#  'meteorological': None,
#  'metrics': 'Q12796440',
#  'midi': 'Q98777027',
#  'model': 'Q4610556',
#  'model prediction': None,
#  'molecular': None,
#  'motion': 'Q452237',
#  'motion capture': 'Q676252',
#  'motion tracking': None,
#  'movement data': 'Q124815680',
#  'multilingual': 'Q96716753',
#  'multimodal': None,
#  'network': 'Q7000691',
#  'network capture': None,
#  'network flow': None,
#  'network traffic': None,
#  'neural': 'Q57032909',
#  'neuroimaging': 'Q551875',
#  'neurophysiological': None,
#  'nirs': 'Q131462388',
#  'notebook': 'Q43013',
#  'numeric': 'Q3249849',
#  'numerical': None,
#  'odometry': 'Q2014717',
#  'optical flow': 'Q736111',
#  'other': 'Q86630688',
#  'parameter': 'Q1413083',
#  'physical interaction': None,
#  'physics': 'Q413',
#  'physiological': None,
#  'physiological signal': None,
#  'point cloud': 'Q1899648',
#  'polarisation': 'Q121463492',
#  'pose': 'Q30603704',
#  'pose information': None,
#  'positional data': None,
#  'procedurally generated data': None,
#  'protein': 'Q8054',
#  'protein structure': 'Q735188',
#  'radar': 'Q47528',
#  'radio': 'Q37169573',
#  'radio frequency': 'Q3396184',
#  'raster': 'Q66043426',
#  'real world data': 'Q55631277',
#  'reconstruction': 'Q2478058',
#  'reference': 'Q121769',
#  'respiration': 'Q15753091',
#  'result': 'Q2995644',
#  'robot joint angle': None,
#  'robotics': 'Q170978',
#  'saliency map': None,
#  'scalar field': 'Q193460',
#  'script': 'Q3691017',
#  'segmentation': 'Q1423946',
#  'segmentation map': None,
#  'segmentation mask': None,
#  'semantic representation': None,
#  'sensor': 'Q37453697',
#  'sequence': 'Q20937557',
#  'sequential data': None,
#  'sign language': 'Q34228',
#  'signal': 'Q19718090',
#  'simulation': 'Q45045',
#  'skeleton': 'Q186190',
#  'sketch': 'Q5078274',
#  'social': 'Q345367',
#  'social context': None,
#  'social network': 'Q2715623',
#  'software': 'Q7397',
#  'spatial': None,
#  'spatial coordinate': None,
#  'spatial relation': 'Q2178623',
#  'spatiotemporal': None,
#  'spectra': 'Q130556645',
#  'spiking neural data': None,
#  'state tracking': None,
#  'structural': None,
#  'structure': 'Q15709970',
#  'structured data': 'Q26813700',
#  'structured text': 'Q1753738',
#  'surface normals': None,
#  'symbol': 'Q80071',
#  'symbolic': 'Q919092',
#  'syntactic analysis': None,
#  'synthetic data': 'Q7662746',
#  'system log': None,
#  'table': 'Q14748',
#  'tabular': 'Q13402984',
#  'tactile': 'Q28136816',
#  'temporal': 'Q98889848',
#  'temporal graph': None,
#  'temporal sequence': None,
#  'text': 'Q234460',
#  'text-image interaction': None,
#  'time': 'Q43297',
#  'time series': 'Q186588',
#  'timestamp': 'Q186885',
#  'touch': 'Q307221',
#  'trajectory': 'Q193139',
#  'url': 'Q42253',
#  'user data': None,
#  'user metadata': None,
#  'vector': 'Q107994',
#  'video': 'Q625525',
#  'virtual api': None,
#  'virtual environment': 'Q55950686',
#  'virtual reality': 'Q170519',
#  'visual': None,
#  'visualization': 'Q451553',
#  'vr': None,
#  'web': 'Q37564491',
#  'web structure': None,
#  'wireless': 'Q8026812'}

# %%
none_qid_entries = {word: qid for word, qid in qid_mapping.items() if qid is None}
for word, qid in none_qid_entries.items():
    print(f"'{word}': {qid}")
# Out:
# '3d annotation': None
# '3d body skeleton': None
# '3d model parameter': None
# '3d pose annotation': None
# '3d scalar field': None
# 'control stream': None
# 'external tool': None
# 'network capture': None
# 'pose information': None
# 'positional data': None
# 'procedurally generated data': None
# 'robot joint angle': None
# 'spiking neural data': None
# 'text-image interaction': None
# 'user metadata': None
# 'virtual api': None

# %%
qid_entries = {word: qid for word, qid in qid_mapping.items() if qid is not None}
for word, qid in qid_entries.items():
    print(f"'{word}': {qid}")
# Out:
# '2d': Q2815842
# '2d image': Q51593562
# '2d structure': Q51941403
# '3d': Q189177
# '3d coordinate': Q129926772
# '3d environment': Q54457512
# '3d landmark': Q38215966
# '3d layout': Q128229676
# '3d lidar': Q119704469
# '3d mesh': Q37115292
# '3d model': Q3859833
# '3d motion': Q46043750
# '3d motion capture': Q104559750
# '3d object': Q35459920
# '3d point': Q128304176
# '3d point cloud': Q128304176
# '3d pose': Q4636322
# '3d scan': Q94701573
# '3d simulation': Q45045
# '3d skeletal': Q37647591
# '3d skeleton': Q49885563
# '3d structure': Q105696529
# '3d trajectory': Q92923419
# '4d': Q412616
# 'action': Q188473
# 'activity': Q1656682
# 'algorithm': Q8366
# 'alpha matte': Q57590135
# 'analytic': Q485223
# 'anatomical': Q2725967
# 'animation': Q202866
# 'annotation': Q857525
# 'application': Q166142
# 'audio': Q482994
# 'audiovisual': Q758901
# 'behavioral': Q846566
# 'binary': Q50053
# 'bioassay data': Q97060518
# 'biochemical': Q7094
# 'biological': Q7094
# 'biomarker': Q864574
# 'biometric': Q177765
# 'biosample': Q96797376
# 'biosignal': Q644240
# 'blockchain': Q20514253
# 'body motion': Q79782
# 'bounding box': Q1434060
# 'box': Q987767
# 'brain signal': Q34201792
# 'calibration': Q736777
# 'camera': Q15328
# 'camera parameter': Q130456983
# 'camera pose': Q51477846
# 'categorical': Q2004972
# 'chemical': Q902623
# 'chemical structure': Q500256
# 'code': Q37141227
# 'configuration': Q1866689
# 'container': Q987767
# 'control': Q11175
# 'cwl': Q8994
# 'data': Q821542
# 'data array': Q129425988
# 'data file': Q5227290
# 'data stream': Q1172540
# 'database': Q8513
# 'demographic': Q37732
# 'depth': Q930412
# 'depth map': Q2940499
# 'document': Q49848
# 'drive': Q10349745
# 'dynamical': Q638328
# 'ecg': Q79785
# 'edge map': Q35963933
# 'eeg': Q179965
# 'electromyography': Q27710763
# 'electrophysiological': Q110491581
# 'embedding': Q980509
# 'emotion': Q5373749
# 'environment': Q2249676
# 'environmental condition': Q110792565
# 'eog': Q976494
# 'epigenetic': Q26939
# 'evaluation metric': Q130272711
# 'event': Q1190554
# 'event stream': Q104622942
# 'eye gaze': Q117715026
# 'eye tracking': Q970687
# 'feature': Q814254
# 'feature vector': Q1921842
# 'file': Q59221146
# 'fmri': Q903809
# 'game': Q11410
# 'gameplay': Q1150958
# 'gaze': Q16870142
# 'genetic': Q7162
# 'genomic': Q222046
# 'genomic sequence': Q104595271
# 'geo information': Q96703395
# 'geographical': Q1071
# 'geolocation': Q819122
# 'geometry': Q8087
# 'geospatial': Q107108718
# 'gesture': Q371174
# 'gnss': Q179435
# 'gnss/ins': Q109324281
# 'gps': Q18822
# 'graph': Q17514
# 'ground truth': Q370766
# 'grounding': Q14920473
# 'haptic': Q3030571
# 'identifier': Q853614
# 'image': Q478798
# 'imu': Q12712164
# 'index': Q1860469
# 'inertial': Q570607
# 'interaction': Q4641997
# 'interaction log': Q3153081
# 'interactive': Q941594
# 'interactive environment': Q47215247
# 'json': Q2063
# 'key point': Q11983068
# 'kinematic': Q11476
# 'kinesthetic': Q1742319
# 'knowledge base': Q593744
# 'knowledge graph': Q648625
# 'label': Q82799
# 'laser scan': Q1361664
# 'lidar': Q504027
# 'link': Q213660
# 'list': Q13406463
# 'location': Q2221906
# 'log': Q39304236
# 'magnetoencephalography': Q384188
# 'map': Q4006
# 'mask': Q161524
# 'matrix': Q44337
# 'meta information': Q56758027
# 'metadata': Q180160
# 'meteorological': Q190107
# 'metrics': Q192624
# 'midi': Q98777027
# 'model': Q4610556
# 'model prediction': Q80931044
# 'molecular': Q7202
# 'motion': Q452237
# 'motion capture': Q676252
# 'motion tracking': Q676252
# 'movement data': Q124815680
# 'multilingual': Q20923490
# 'multimodal': Q66214583
# 'network': Q1301371
# 'network flow': Q26720127
# 'network traffic': Q54366
# 'neural': Q3338704
# 'neuroimaging': Q551875
# 'neurophysiological': Q14912053
# 'nirs': Q131462388
# 'notebook': Q70357595
# 'numeric': Q63116
# 'numerical': Q63116
# 'odometry': Q2014717
# 'optical flow': Q736111
# 'other': Q48270
# 'parameter': Q1413083
# 'physical interaction': Q104934
# 'physics': Q413
# 'physiological': Q2996394
# 'physiological signal': Q17074885
# 'point cloud': Q1899648
# 'polarisation': Q193760
# 'pose': Q4610556
# 'protein': Q8054
# 'protein structure': Q735188
# 'radar': Q47528
# 'radio': Q14350
# 'radio frequency': Q3396184
# 'raster': Q182270
# 'real world data': Q55631277
# 'reconstruction': Q55074511
# 'reference': Q121769
# 'respiration': Q9530
# 'result': Q2995644
# 'robotics': Q170978
# 'saliency map': Q1469792
# 'scalar field': Q193460
# 'script': Q8192
# 'segmentation': Q2266173
# 'segmentation map': Q128410291
# 'segmentation mask': Q57609232
# 'semantic representation': Q123142295
# 'sensor': Q37453697
# 'sequence': Q20937557
# 'sequential data': Q97612776
# 'sign language': Q34228
# 'signal': Q19718090
# 'simulation': Q1610017
# 'skeleton': Q186190
# 'sketch': Q5078274
# 'social': Q202833
# 'social context': Q64120976
# 'social network': Q2715623
# 'software': Q7397
# 'spatial': Q1938983
# 'spatial coordinate': Q51950995
# 'spatial relation': Q2178623
# 'spatiotemporal': Q110932575
# 'spectra': Q483666
# 'state tracking': Q49158129
# 'structural': Q811979
# 'structure': Q811979
# 'structured data': Q26813700
# 'structured text': Q1753738
# 'surface normals': Q60431395
# 'symbol': Q80071
# 'symbolic': Q919092
# 'syntactic analysis': Q194152
# 'synthetic data': Q7662746
# 'system log': Q124162253
# 'table': Q14748
# 'tabular': Q13402984
# 'tactile': Q18035138
# 'temporal': Q98889848
# 'temporal graph': Q42598848
# 'temporal sequence': Q112887117
# 'text': Q1145976
# 'time': Q43297
# 'time series': Q186588
# 'timestamp': Q186885
# 'touch': Q307221
# 'trajectory': Q193139
# 'url': Q1193907
# 'user data': Q11163
# 'vector': Q427389
# 'video': Q34508
# 'virtual environment': Q444835
# 'virtual reality': Q170519
# 'visual': Q162668
# 'visualization': Q451553
# 'vr': Q170519
# 'web': Q35127
# 'web structure': Q7978426
# 'wireless': Q249

# %%
none_qid_entries = {word: qid for word, qid in qid_mapping_exact.items() if qid is None}
for word, qid in none_qid_entries.items():
    print(f"'{word}': {qid}")
# Out:
# '2d image': None
# '2d structure': None
# '3d annotation': None
# '3d body skeleton': None
# '3d coordinate': None
# '3d environment': None
# '3d landmark': None
# '3d layout': None
# '3d lidar': None
# '3d mesh': None
# '3d model parameter': None
# '3d motion': None
# '3d motion capture': None
# '3d object': None
# '3d point': None
# '3d point cloud': None
# '3d pose': None
# '3d pose annotation': None
# '3d scalar field': None
# '3d scan': None
# '3d simulation': None
# '3d skeletal': None
# '3d skeleton': None
# '3d structure': None
# '3d trajectory': None
# 'alpha matte': None
# 'anatomical': None
# 'behavioral': None
# 'bioassay data': None
# 'biological': None
# 'biometric': None
# 'body motion': None
# 'bounding box': None
# 'brain signal': None
# 'camera parameter': None
# 'camera pose': None
# 'categorical': None
# 'chemical': None
# 'control stream': None
# 'cwl': None
# 'data array': None
# 'demographic': None
# 'dynamical': None
# 'ecg': None
# 'edge map': None
# 'electrophysiological': None
# 'eog': None
# 'epigenetic': None
# 'evaluation metric': None
# 'external tool': None
# 'eye gaze': None
# 'genetic': None
# 'genomic': None
# 'genomic sequence': None
# 'geo information': None
# 'geographical': None
# 'gnss': None
# 'gnss/ins': None
# 'inertial': None
# 'interaction log': None
# 'interactive environment': None
# 'kinesthetic': None
# 'laser scan': None
# 'meta information': None
# 'meteorological': None
# 'model prediction': None
# 'molecular': None
# 'motion tracking': None
# 'multimodal': None
# 'network capture': None
# 'network flow': None
# 'network traffic': None
# 'neurophysiological': None
# 'numerical': None
# 'physical interaction': None
# 'physiological': None
# 'physiological signal': None
# 'pose information': None
# 'positional data': None
# 'procedurally generated data': None
# 'robot joint angle': None
# 'saliency map': None
# 'segmentation map': None
# 'segmentation mask': None
# 'semantic representation': None
# 'sequential data': None
# 'social context': None
# 'spatial': None
# 'spatial coordinate': None
# 'spatiotemporal': None
# 'spiking neural data': None
# 'state tracking': None
# 'structural': None
# 'surface normals': None
# 'syntactic analysis': None
# 'system log': None
# 'temporal graph': None
# 'temporal sequence': None
# 'text-image interaction': None
# 'user data': None
# 'user metadata': None
# 'virtual api': None
# 'visual': None
# 'vr': None
# 'web structure': None

# %%
# Load the words_with_qid.csv file and create a mapping
word_to_qid = {}
with open('words_with_qid.csv', 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        word_to_qid[row['word']] = row['qid']

# %%
# !pip3 install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
# Load the words_no_qid_update.xlsx file
words_no_qid_update = pd.read_excel('words_no_qid_update.xlsx')

# Replace the 'word' column with 'wikidata' column
words_no_qid_update['word'] = words_no_qid_update['wiki_word']

# Drop the 'wikidata' column
words_no_qid_update = words_no_qid_update.drop(columns=['wiki_word'])

# %%
# Convert the DataFrame to a dictionary
words_no_qid_update_dict = words_no_qid_update.set_index('word').to_dict()['qid']

# Combine the dictionaries and remove duplicates
combined_data = {**word_to_qid, **words_no_qid_update_dict}

# Save the combined data to a new CSV file
with open('combined_words_with_qid.csv', 'w', encoding='utf-8', newline='') as csvfile:
    fieldnames = ['word', 'qid']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for word, qid in combined_data.items():
        writer.writerow({'word': word, 'qid': qid})

print("Combined data has been saved to combined_words_with_qid.csv.")
# Out:
# Combined data has been saved to combined_words_with_qid.csv.

# %%
#sort the combined data
combined_data_df = pd.read_csv('combined_words_with_qid.csv',index_col=0)
combined_data_df = combined_data_df.sort_values(by='word').reset_index(drop=True)
# Save the sorted data to a new CSV file
combined_data_df.to_csv('combined_words_with_qid.csv', sep=',', index=False, header=True)

# %%
combined_data_df = pd.read_csv('combined_words_with_qid.csv')
all_qids = combined_data_df['qid'].dropna().unique().tolist()

print(len(all_qids))

batch_size = 50  
chunk_size = 150 

# Split the list into chunks
def split_chunks(lst, size):
    return [lst[i:i+size] for i in range(0, len(lst), size)]

batches = split_chunks(all_qids, batch_size)  
all_qids_chunks = split_chunks(all_qids, chunk_size)
# Out:
# 226

# %% [markdown]
# ### Typical properties to link one item to another:
#
# **Comparing items ...**
# said to be the same as (P460)
# different from (P1889) - (different from, but sometimes confused with ...)
#
# **Item is part of ...**
# part of (P361) - (section of .../ contained within .../ pieces of ...)
# instance of (P31) - (is an example of ...)
# subclass of (P279) - (is a subset of ...)
# facet of (P1269) - (aspect of .../ subitem of .../ a broader perspective on the same topic is offered by ...)
# has characteristic (P1552) - (has characteristic .../ defining feature .../ inherent property ...)
#
# **Item contains ...**
# has part(s) (P527) - (contains ...)
# has part(s) of the class (P2670) (has parts that are instances of .../ some parts form subclass of ...)
#
# **Others**
# related property (P1659) (used to indicate another property that might provide additional information about the subject)
#
# file format (P2701)

# %% [markdown]
# ### Two-end

# %%
import random
# Disable SSL verification
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# 初始化SPARQL
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setMethod(POST) 
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader("User-Agent", "MyWikidataBot/1.0 (yu.wang3@uzh.ch)")

def query_relations(qids_batch, word2_chunk, max_retries=5):
    """查询当前批次QID与某一块word2_chunk的关系"""
    qids_values = " ".join([f"wd:{qid}" for qid in qids_batch])
    word2_values = " ".join([f"wd:{qid}" for qid in word2_chunk])
    
    query = f"""
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    
    SELECT ?word ?wordLabel ?relation ?relationLabel ?word2 ?word2Label
    WHERE {{
      VALUES ?word {{ {qids_values} }}
      VALUES ?word2 {{ {word2_values} }}
      # ?word ?relation ?word2 .
      FILTER (?relation IN (wdt:P460, wdt:P1889, wdt:P361, wdt:P31, wdt:P279, wdt:P1269, wdt:P1552, wdt:P527, wdt:P2670, wdt:P1659, wdt:P2701, wdt:P1382))
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    """
    retries = 0
    while retries < max_retries:
        try:
            sparql.setQuery(query)
            results = sparql.query().convert()
            return results["results"]["bindings"]
        except Exception as e:
            if "429" in str(e):
                wait = random.uniform(10, 30)
                print(f"429 error，waiting{wait:.1f}seconds and retry...")
                time.sleep(wait)
                retries += 1
            else:
                print(f"error: {e}")
                return []
    print("Max retries reached.")
    return []

# %%
# query relations
all_results_1 = []
for batch in tqdm(batches, desc="Processing"):
    for chunk in all_qids_chunks:
        results = query_relations(batch, chunk)
        all_results_1.extend(results)
        time.sleep(random.uniform(1, 3))  # 短等待避免频繁429
    time.sleep(random.uniform(5, 10))     # 批次间较长等待

print(f"Totally find {len(all_results_1)} relations。")
# Out:
# Processing: 100%|██████████| 5/5 [00:57<00:00, 11.52s/it]
# Totally find 53 relations。

# %%
# Store results
def store_results_1(all_results):
    output = set()
    
    for result in all_results:
        word = result['word']['value'].split('/')[-1] 
        word_label = result.get('wordLabel', {}).get('value', "")  
        relation = result['relation']['value'].split('/')[-1]
        #relation_label = result.get('relationLabel', {}).get('value', "")  
        word2 = result['word2']['value'].split('/')[-1] 
        word2_label = result.get('word2Label', {}).get('value', "")  

        # **去重**
        triple = (word, word_label, relation, word2, word2_label)
        output.add(triple)

    return [dict(zip(["word", "word_label", "relation", "word2", "word2_label"], row)) for row in output]

# %%
# Convert to DataFrame and save to CSV
output_df = pd.DataFrame(store_results_1(all_results_1))
output_df.to_csv('modality_relations_two_end.csv', index=False)

# %% [markdown]
# ### One-end

# %%
# Query the SPARQL endpoint for each batch
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)

def query_relations_ood(qids_batch):
    # Create SPARQL query for the batch
    qids_values = " ".join([f"wd:{qid}" for qid in qids_batch])
    
    query = f"""
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    
    SELECT ?word ?wordLabel ?relation ?relationLabel ?relatedWord ?relatedWordLabel
    WHERE {{
      VALUES ?word {{ {qids_values} }}
      # VALUES ?relatedWord {{ {qids_values} }}
      # ?word ?relation ?relatedWord .
      FILTER (?relation IN (wdt:P460, wdt:P1889, wdt:P361, wdt:P31, wdt:P279, wdt:P1269, wdt:P1552, wdt:P527, wdt:P2670, wdt:P1659)) .
      
      # Retrieve labels for word, relation, and relatedWord
      SERVICE wikibase:label {{
        bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en".
        # ?word rdfs:label ?wordLabel .
        # ?relation rdfs:label ?relationLabel .
        # ?relatedWord rdfs:label ?relatedWordLabel .
      }}
    }}
    """
    sparql.setQuery(query)
    results = sparql.query().convert()
    return results["results"]["bindings"]

# %%
# Disable SSL verification
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# Process each batch
# two-end
all_results = []
for i, batch in enumerate(tqdm(batches, desc="Processing batches")):
    qids_batch = batch["qid"].dropna().tolist()
    batch_results = query_relations(qids_batch)
    #print(batch_results)
    all_results.extend(batch_results)
    time.sleep(5)  # To avoid overloading the SPARQL endpoint
# Out:
# Processing batches: 100%|██████████| 5/5 [00:26<00:00,  5.33s/it]

# %%
all_results
# Out:
# [{'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q864574'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biomarker'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'anatomy'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q20514253'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'blockchain'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'database'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q42848'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1172540'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q42848'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data stream'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1643805'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q42848'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'container'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2285707'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q42848'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'categorical variable'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q37732'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1071'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'demography'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'geography'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q26939'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7162'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'epigenetics'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'genetics'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q26939'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7162'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'epigenetics'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'genetics'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q222046'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7162'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'genomics'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'genetics'}},
#  {'word': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q124815680'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q79782'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1269'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'movement data'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'motion'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q384188'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q551875'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'magnetoencephalography'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'neuroimaging'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q33002955'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q593744'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'knowledge graph'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'knowledge base'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q45045'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q413'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'simulation'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'physics'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2178623'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q121769'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'spatial relation'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'reference'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8054'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q735188'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'protein'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'protein structure'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q55950686'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q170519'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'virtual environment'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'virtual reality'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q170519'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q55950686'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'virtual reality'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'virtual environment'}}]

# %%
# Process each batch
# one-end
all_results_ood = []
for i, batch in enumerate(tqdm(batches, desc="Processing batches")):
    qids_batch = batch["qid"].dropna().tolist()
    batch_results = query_relations_ood(qids_batch)
    #print(batch_results)
    all_results_ood.extend(batch_results)
    time.sleep(3)  # To avoid overloading the SPARQL endpoint
# Out:
# Processing batches: 100%|██████████| 5/5 [00:22<00:00,  4.59s/it]

# %%
all_results_ood
# Out:
# [{'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2465832'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'branch of science'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q4671286'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'academic major'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11862829'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'academic discipline'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7991'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'natural science'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q864928'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'life sciences'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q431'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'zoology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q441'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'botany'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q514'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'anatomy'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7094'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biochemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7100'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biophysics'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7108'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biotechnology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7141'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'cell biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7150'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'ecology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7162'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'genetics'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7175'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'mycology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7193'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'microbiology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q177005'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'computational biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q183252'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'morphology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q840400'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'evolutionary biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2728012'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'neurobiology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q4785356'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'archaeobiology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q105582462'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biology of colour'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1063'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'evolution'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q420'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q522190'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'biology'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biological nomenclature'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q28598684'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'branch of biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q420'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q420'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11190'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'medicine'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q4021'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'plant anatomy'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q220384'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'zootomy'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q819121'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'osteology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q948647'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'neuroanatomy'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q514'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q13429539'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'anatomy'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Anatomy'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1047113'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'field of study'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2267705'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'field of study'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2465832'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'branch of science'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q4671286'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'academic major'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11862829'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'academic discipline'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q14632398'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'physical sciences'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q909510'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'general chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2346'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'analytical chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7094'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biochemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11165'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'inorganic chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11351'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'organic chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11372'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'physical chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q321150'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'theoretical chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q321355'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'environmental chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q369472'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'computational chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q750446'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'polymer chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q910172'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'food chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q6503924'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'chemical nomenclature'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11790203'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'branch of chemistry'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2329'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q16535991'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chemistry'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Chemia'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7397'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'software'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q386724'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'work'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q20920559'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'procedure'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q395'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'mathematics'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q21198'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'computer science'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q13636890'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'algorithmics'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1296251'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'algorithmic efficiency'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q5157286'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'computational complexity'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7595718'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'algorithmic stability'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8366'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q22349237'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'algorithm'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Algorithm'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q386724'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'work'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q494756'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1172284'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'data set'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q59138870'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'digital object'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1630548'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'host'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q59138835'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'data base'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q42848'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q176165'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'database management system'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1054115'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'integrity constraints'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1147639'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'data dictionary'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2470517'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'record'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8513'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q59138835'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'database'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'data base'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q96634632'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'psychology concept'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2083958'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'pattern'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2990593'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'animal behavior'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q3769299'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'human behavior'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q4026292'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'action'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q108427150'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'system behaviour'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1269'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q9418'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'psychology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1299714'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'habit'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1375683'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'normality'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2515887'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'pattern of behavior'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2724302'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'abnormality'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1206352'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Behaviour'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2515872'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Verhalten'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q9332'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q60796659'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'behavior'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Behavior'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7048977'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'abstract entity'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7048977'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'abstract entity'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7048977'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'abstract entity'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7048977'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'abstract entity'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q40735'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate origin'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q40735'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate origin'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q40735'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate origin'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q40735'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate origin'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1783819'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate axis'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1783819'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate axis'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1783819'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate axis'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11210'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P2670'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q3250736'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate system'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'coordinate'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11425'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1001378'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'animation'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'cinematic technique'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11425'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q932586'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'animation'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'filmmaking'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11425'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q130285417'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'animation'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'animation'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15328'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1439598'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'camera'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'photo equipment'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15328'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1751850'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'camera'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'optical instrument'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15328'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2424752'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'camera'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'product'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15328'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q192234'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'camera'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'camera lens'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15328'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q209871'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'camera'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'system camera'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15328'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q4410572'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'camera'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'photosensitive materials'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15328'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q18180969'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'camera'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Kamera'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42848'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11028'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'information'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42848'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q59138835'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'data base'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42848'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1552'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q190087'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'},
#   'relatedWordLabel': {'xml:lang': 'en',
# ...
#    'type': 'literal',
#    'value': 'Sensor'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q55631277'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q42848'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Real world data'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'data'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q66043426'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q18127'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Raster'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'record label'}},
#  {'word': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q121463492'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q3305213'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Polarisation'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'painting'}},
#  {'word': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q130556645'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q4830453'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'SPECTRA'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'business'}},
#  {'word': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q130556645'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q6881511'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'SPECTRA'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'enterprise'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q14748'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q14745'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'table'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'furniture'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q14748'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P527'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q56056049'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'table'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'furniture leg'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q14748'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q14749'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'table'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Table'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q14748'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q496946'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'table'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'table'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q317623'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'technical standard'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q61694'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Uniform Resource Identifier'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q61694'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Uniform Resource Identifier'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11135'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'IP address'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q61694'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Uniform Resource Identifier'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q76497'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URN'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q440611'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q42253'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q58494516'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'URL'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'wikilink'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43297'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q41298'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Time'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'magazine'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43297'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q847906'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Time'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'online magazine'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43297'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1684600'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Time'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'news magazine'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43297'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q50008'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Time'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'The Times'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43297'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q124535786'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Time'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Time Magazine'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q80071'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1272626'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'symbol'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'representation'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q80071'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q3695082'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'symbol'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'sign'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q80071'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2001982'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'symbol'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'notation'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q80071'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q3695082'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'symbol'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'sign'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q80071'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11634359'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'symbol'},
#   'relatedWordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': '0411'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q107994'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q7239'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'vector'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'organism'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q107994'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11494956'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'vector'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'source of infection'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q107994'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q11385914'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'vector'},
#   'relatedWordLabel': {'type': 'literal', 'value': 'Q11385914'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q107994'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1269'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q133805'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'vector'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'epidemiology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q107994'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P1889'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q427389'},
#   'wordLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'vector'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'genetic vector'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q162668'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P31'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q2996394'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'visual perception'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'biological process'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q162668'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q160402'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'visual perception'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'perception'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q162668'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P279'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q14859561'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'visual perception'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'sensory perception of light stimulus'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q162668'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1051623'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'visual perception'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'five wits'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q162668'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P361'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q77468620'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'visual perception'},
#   'relatedWordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'psychology terminology'}},
#  {'word': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q162668'},
#   'relation': {'type': 'uri',
#    'value': 'http://www.wikidata.org/prop/direct/P460'},
#   'relatedWord': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q760329'},
#   'wordLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'visual perception'},
#   'relatedWordLabel': {'type': 'literal', 'value': 'Q760329'}},
#  ...]

# %%
# Store results
def store_results(all_results):
    output = []
    
    for result in all_results:
        word = result['word']['value'].split('/')[-1] 
        word_label = result.get('wordLabel', {}).get('value', "")  
        relation = result['relation']['value'].split('/')[-1]
        #relation_label = result.get('relationLabel', {}).get('value', "")  
        related_word = result['relatedWord']['value'].split('/')[-1] 
        related_word_label = result.get('relatedWordLabel', {}).get('value', "")  

        output.append({
            'word': word,
            'word_label': word_label,
            'relation': relation,
            #'relation_label': relation_label, 
            'related_word': related_word,
            'related_word_label': related_word_label
        })
    
    return output

# %%
store_results(all_results)
# Out:
# [{'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P279',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P361',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q864574',
#   'word_label': 'biomarker',
#   'relation': 'P361',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q514',
#   'related_word_label': 'anatomy'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P279',
#   'related_word': 'Q8513',
#   'related_word_label': 'database'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P527',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q1172540',
#   'word_label': 'data stream',
#   'relation': 'P527',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q1643805',
#   'word_label': 'container',
#   'relation': 'P279',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q2285707',
#   'word_label': 'categorical variable',
#   'relation': 'P279',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q37732',
#   'word_label': 'demography',
#   'relation': 'P279',
#   'related_word': 'Q1071',
#   'related_word_label': 'geography'},
#  {'word': 'Q26939',
#   'word_label': 'epigenetics',
#   'relation': 'P279',
#   'related_word': 'Q7162',
#   'related_word_label': 'genetics'},
#  {'word': 'Q26939',
#   'word_label': 'epigenetics',
#   'relation': 'P361',
#   'related_word': 'Q7162',
#   'related_word_label': 'genetics'},
#  {'word': 'Q222046',
#   'word_label': 'genomics',
#   'relation': 'P279',
#   'related_word': 'Q7162',
#   'related_word_label': 'genetics'},
#  {'word': 'Q124815680',
#   'word_label': 'movement data',
#   'relation': 'P1269',
#   'related_word': 'Q79782',
#   'related_word_label': 'motion'},
#  {'word': 'Q384188',
#   'word_label': 'magnetoencephalography',
#   'relation': 'P279',
#   'related_word': 'Q551875',
#   'related_word_label': 'neuroimaging'},
#  {'word': 'Q33002955',
#   'word_label': 'knowledge graph',
#   'relation': 'P279',
#   'related_word': 'Q593744',
#   'related_word_label': 'knowledge base'},
#  {'word': 'Q45045',
#   'word_label': 'simulation',
#   'relation': 'P361',
#   'related_word': 'Q413',
#   'related_word_label': 'physics'},
#  {'word': 'Q2178623',
#   'word_label': 'spatial relation',
#   'relation': 'P1552',
#   'related_word': 'Q121769',
#   'related_word_label': 'reference'},
#  {'word': 'Q8054',
#   'word_label': 'protein',
#   'relation': 'P1552',
#   'related_word': 'Q735188',
#   'related_word_label': 'protein structure'},
#  {'word': 'Q55950686',
#   'word_label': 'virtual environment',
#   'relation': 'P1889',
#   'related_word': 'Q170519',
#   'related_word_label': 'virtual reality'},
#  {'word': 'Q170519',
#   'word_label': 'virtual reality',
#   'relation': 'P1889',
#   'related_word': 'Q55950686',
#   'related_word_label': 'virtual environment'}]

# %%
# Convert to DataFrame and save to CSV
output_df = pd.DataFrame(store_results(all_results))
output_df.to_csv('modality_relations_two_end.csv', index=False)

# %%
store_results(all_results_ood)
# Out:
# [{'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P31',
#   'related_word': 'Q2465832',
#   'related_word_label': 'branch of science'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P31',
#   'related_word': 'Q4671286',
#   'related_word_label': 'academic major'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P279',
#   'related_word': 'Q7991',
#   'related_word_label': 'natural science'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P460',
#   'related_word': 'Q864928',
#   'related_word_label': 'life sciences'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q431',
#   'related_word_label': 'zoology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q441',
#   'related_word_label': 'botany'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q514',
#   'related_word_label': 'anatomy'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7094',
#   'related_word_label': 'biochemistry'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7100',
#   'related_word_label': 'biophysics'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7108',
#   'related_word_label': 'biotechnology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7141',
#   'related_word_label': 'cell biology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7150',
#   'related_word_label': 'ecology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7162',
#   'related_word_label': 'genetics'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7175',
#   'related_word_label': 'mycology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q7193',
#   'related_word_label': 'microbiology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q177005',
#   'related_word_label': 'computational biology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q183252',
#   'related_word_label': 'morphology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q840400',
#   'related_word_label': 'evolutionary biology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q2728012',
#   'related_word_label': 'neurobiology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q4785356',
#   'related_word_label': 'archaeobiology'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P527',
#   'related_word': 'Q105582462',
#   'related_word_label': 'biology of colour'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P1552',
#   'related_word': 'Q1063',
#   'related_word_label': 'evolution'},
#  {'word': 'Q420',
#   'word_label': 'biology',
#   'relation': 'P1552',
#   'related_word': 'Q522190',
#   'related_word_label': 'biological nomenclature'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P31',
#   'related_word': 'Q28598684',
#   'related_word_label': 'branch of biology'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P279',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P361',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P361',
#   'related_word': 'Q11190',
#   'related_word_label': 'medicine'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P527',
#   'related_word': 'Q4021',
#   'related_word_label': 'plant anatomy'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P527',
#   'related_word': 'Q220384',
#   'related_word_label': 'zootomy'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P527',
#   'related_word': 'Q819121',
#   'related_word_label': 'osteology'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P527',
#   'related_word': 'Q948647',
#   'related_word_label': 'neuroanatomy'},
#  {'word': 'Q514',
#   'word_label': 'anatomy',
#   'relation': 'P1889',
#   'related_word': 'Q13429539',
#   'related_word_label': 'Anatomy'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P31',
#   'related_word': 'Q1047113',
#   'related_word_label': 'field of study'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P31',
#   'related_word': 'Q2267705',
#   'related_word_label': 'field of study'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P31',
#   'related_word': 'Q2465832',
#   'related_word_label': 'branch of science'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P31',
#   'related_word': 'Q4671286',
#   'related_word_label': 'academic major'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P279',
#   'related_word': 'Q14632398',
#   'related_word_label': 'physical sciences'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P460',
#   'related_word': 'Q909510',
#   'related_word_label': 'general chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q2346',
#   'related_word_label': 'analytical chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q7094',
#   'related_word_label': 'biochemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q11165',
#   'related_word_label': 'inorganic chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q11351',
#   'related_word_label': 'organic chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q11372',
#   'related_word_label': 'physical chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q321150',
#   'related_word_label': 'theoretical chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q321355',
#   'related_word_label': 'environmental chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q369472',
#   'related_word_label': 'computational chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q750446',
#   'related_word_label': 'polymer chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P527',
#   'related_word': 'Q910172',
#   'related_word_label': 'food chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P1552',
#   'related_word': 'Q6503924',
#   'related_word_label': 'chemical nomenclature'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P1552',
#   'related_word': 'Q11790203',
#   'related_word_label': 'branch of chemistry'},
#  {'word': 'Q2329',
#   'word_label': 'chemistry',
#   'relation': 'P1889',
#   'related_word': 'Q16535991',
#   'related_word_label': 'Chemia'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P279',
#   'related_word': 'Q7397',
#   'related_word_label': 'software'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P279',
#   'related_word': 'Q386724',
#   'related_word_label': 'work'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P279',
#   'related_word': 'Q20920559',
#   'related_word_label': 'procedure'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P361',
#   'related_word': 'Q395',
#   'related_word_label': 'mathematics'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P361',
#   'related_word': 'Q21198',
#   'related_word_label': 'computer science'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P361',
#   'related_word': 'Q13636890',
#   'related_word_label': 'algorithmics'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P1552',
#   'related_word': 'Q1296251',
#   'related_word_label': 'algorithmic efficiency'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P1552',
#   'related_word': 'Q5157286',
#   'related_word_label': 'computational complexity'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P1552',
#   'related_word': 'Q7595718',
#   'related_word_label': 'algorithmic stability'},
#  {'word': 'Q8366',
#   'word_label': 'algorithm',
#   'relation': 'P1889',
#   'related_word': 'Q22349237',
#   'related_word_label': 'Algorithm'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P279',
#   'related_word': 'Q386724',
#   'related_word_label': 'work'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P279',
#   'related_word': 'Q494756',
#   'related_word_label': 'data'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P279',
#   'related_word': 'Q1172284',
#   'related_word_label': 'data set'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P279',
#   'related_word': 'Q59138870',
#   'related_word_label': 'digital object'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P361',
#   'related_word': 'Q1630548',
#   'related_word_label': 'host'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P460',
#   'related_word': 'Q59138835',
#   'related_word_label': 'data base'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P527',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P527',
#   'related_word': 'Q176165',
#   'related_word_label': 'database management system'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P527',
#   'related_word': 'Q1054115',
#   'related_word_label': 'integrity constraints'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P527',
#   'related_word': 'Q1147639',
#   'related_word_label': 'data dictionary'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P527',
#   'related_word': 'Q2470517',
#   'related_word_label': 'record'},
#  {'word': 'Q8513',
#   'word_label': 'database',
#   'relation': 'P527',
#   'related_word': 'Q59138835',
#   'related_word_label': 'data base'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P31',
#   'related_word': 'Q96634632',
#   'related_word_label': 'psychology concept'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P279',
#   'related_word': 'Q2083958',
#   'related_word_label': 'pattern'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P527',
#   'related_word': 'Q2990593',
#   'related_word_label': 'animal behavior'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P527',
#   'related_word': 'Q3769299',
#   'related_word_label': 'human behavior'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P527',
#   'related_word': 'Q4026292',
#   'related_word_label': 'action'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P527',
#   'related_word': 'Q108427150',
#   'related_word_label': 'system behaviour'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1269',
#   'related_word': 'Q9418',
#   'related_word_label': 'psychology'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1552',
#   'related_word': 'Q1299714',
#   'related_word_label': 'habit'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1552',
#   'related_word': 'Q1375683',
#   'related_word_label': 'normality'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1552',
#   'related_word': 'Q2515887',
#   'related_word_label': 'pattern of behavior'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1552',
#   'related_word': 'Q2724302',
#   'related_word_label': 'abnormality'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1889',
#   'related_word': 'Q1206352',
#   'related_word_label': 'Behaviour'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1889',
#   'related_word': 'Q2515872',
#   'related_word_label': 'Verhalten'},
#  {'word': 'Q9332',
#   'word_label': 'behavior',
#   'relation': 'P1889',
#   'related_word': 'Q60796659',
#   'related_word_label': 'Behavior'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P31',
#   'related_word': 'Q7048977',
#   'related_word_label': 'abstract entity'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P31',
#   'related_word': 'Q7048977',
#   'related_word_label': 'abstract entity'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P31',
#   'related_word': 'Q7048977',
#   'related_word_label': 'abstract entity'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P31',
#   'related_word': 'Q7048977',
#   'related_word_label': 'abstract entity'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q40735',
#   'related_word_label': 'coordinate origin'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q40735',
#   'related_word_label': 'coordinate origin'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q40735',
#   'related_word_label': 'coordinate origin'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q40735',
#   'related_word_label': 'coordinate origin'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q1783819',
#   'related_word_label': 'coordinate axis'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q1783819',
#   'related_word_label': 'coordinate axis'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q1783819',
#   'related_word_label': 'coordinate axis'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P2670',
#   'related_word': 'Q3250736',
#   'related_word_label': 'coordinate'},
#  {'word': 'Q11425',
#   'word_label': 'animation',
#   'relation': 'P31',
#   'related_word': 'Q1001378',
#   'related_word_label': 'cinematic technique'},
#  {'word': 'Q11425',
#   'word_label': 'animation',
#   'relation': 'P279',
#   'related_word': 'Q932586',
#   'related_word_label': 'filmmaking'},
#  {'word': 'Q11425',
#   'word_label': 'animation',
#   'relation': 'P1889',
#   'related_word': 'Q130285417',
#   'related_word_label': 'animation'},
#  {'word': 'Q15328',
#   'word_label': 'camera',
#   'relation': 'P279',
#   'related_word': 'Q1439598',
#   'related_word_label': 'photo equipment'},
#  {'word': 'Q15328',
#   'word_label': 'camera',
#   'relation': 'P279',
#   'related_word': 'Q1751850',
#   'related_word_label': 'optical instrument'},
#  {'word': 'Q15328',
#   'word_label': 'camera',
#   'relation': 'P279',
#   'related_word': 'Q2424752',
#   'related_word_label': 'product'},
#  {'word': 'Q15328',
#   'word_label': 'camera',
#   'relation': 'P527',
#   'related_word': 'Q192234',
#   'related_word_label': 'camera lens'},
#  {'word': 'Q15328',
#   'word_label': 'camera',
#   'relation': 'P527',
#   'related_word': 'Q209871',
#   'related_word_label': 'system camera'},
#  {'word': 'Q15328',
#   'word_label': 'camera',
#   'relation': 'P527',
#   'related_word': 'Q4410572',
#   'related_word_label': 'photosensitive materials'},
#  {'word': 'Q15328',
#   'word_label': 'camera',
#   'relation': 'P1889',
#   'related_word': 'Q18180969',
#   'related_word_label': 'Kamera'},
#  {'word': 'Q42848',
#   'word_label': 'data',
#   'relation': 'P279',
#   'related_word': 'Q11028',
#   'related_word_label': 'information'},
#  {'word': 'Q42848',
#   'word_label': 'data',
#   'relation': 'P361',
#   'related_word': 'Q59138835',
#   'related_word_label': 'data base'},
#  {'word': 'Q42848',
#   'word_label': 'data',
#   'relation': 'P1552',
#   'related_word': 'Q190087',
#   'related_word_label': 'data type'},
#  {'word': 'Q42848',
#   'word_label': 'data',
#   'relation': 'P1552',
#   'related_word': 'Q494823',
#   'related_word_label': 'data format'},
#  {'word': 'Q42848',
#   'word_label': 'data',
#   'relation': 'P1552',
#   'related_word': 'Q5227257',
#   'related_word_label': 'data classification (data management)'},
#  {'word': 'Q42848',
#   'word_label': 'data',
#   'relation': 'P1889',
#   'related_word': 'Q680158',
#   'related_word_label': 'Data'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P31',
#   'related_word': 'Q1047113',
#   'related_word_label': 'field of study'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P31',
#   'related_word': 'Q2267705',
#   'related_word_label': 'field of study'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P279',
#   'related_word': 'Q23808',
#   'related_word_label': 'computer interface'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P279',
#   'related_word': 'Q132364',
#   'related_word_label': 'communication protocol'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P279',
#   'related_word': 'Q241317',
#   'related_word_label': 'computing platform'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P1269',
#   'related_word': 'Q21198',
#   'related_word_label': 'computer science'},
#  {'word': 'Q165194',
#   'word_label': 'application programming interface',
#   'relation': 'P1269',
#   'related_word': 'Q80993',
#   'related_word_label': 'software engineering'},
#  {'word': 'Q166142',
#   'word_label': 'application',
#   'relation': 'P31',
#   'related_word': 'Q17155032',
#   'related_word_label': 'software category'},
#  {'word': 'Q166142',
#   'word_label': 'application',
#   'relation': 'P279',
#   'related_word': 'Q7397',
#   'related_word_label': 'software'},
#  {'word': 'Q166142',
#   'word_label': 'application',
#   'relation': 'P527',
#   'related_word': 'Q40056',
#   'related_word_label': 'computer program'},
#  {'word': 'Q166142',
#   'word_label': 'application',
#   'relation': 'P1552',
#   'related_word': 'Q4781497',
#   'related_word_label': 'application security'},
#  {'word': 'Q177765',
#   'word_label': 'biometrics',
#   'relation': 'P31',
#   'related_word': 'Q336',
#   'related_word_label': 'science'},
#  {'word': 'Q177765',
#   'word_label': 'biometrics',
#   'relation': 'P31',
#   'related_word': 'Q91615393',
#   'related_word_label': 'Wikidata items that need to be split'},
#  {'word': 'Q177765',
#   'word_label': 'biometrics',
#   'relation': 'P279',
#   'related_word': 'Q12453',
#   'related_word_label': 'measurement'},
#  {'word': 'Q186152',
#   'word_label': 'array data structure',
#   'relation': 'P279',
#   'related_word': 'Q175263',
#   'related_word_label': 'data structure'},
#  {'word': 'Q186152',
#   'word_label': 'array data structure',
#   'relation': 'P279',
#   'related_word': 'Q17008256',
#   'related_word_label': 'collection'},
#  {'word': 'Q186152',
#   'word_label': 'array data structure',
#   'relation': 'P1552',
#   'related_word': 'Q253405',
#   'related_word_label': 'connectedness'},
#  {'word': 'Q186152',
#   'word_label': 'array data structure',
#   'relation': 'P1552',
#   'related_word': 'Q1868547',
#   'related_word_label': 'locality of reference'},
#  {'word': 'Q186152',
#   'word_label': 'array data structure',
#   'relation': 'P1889',
#   'related_word': 'Q15777392',
#   'related_word_label': 'Tablica'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P31',
#   'related_word': 'Q18340964',
#   'related_word_label': 'power'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P31',
#   'related_word': 'Q96758092',
#   'related_word_label': 'type of regulation and control'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P279',
#   'related_word': 'Q29017603',
#   'related_word_label': 'control'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P361',
#   'related_word': 'Q9418',
#   'related_word_label': 'psychology'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P361',
#   'related_word': 'Q3565078',
#   'related_word_label': 'tripartite classification of authority'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P1552',
#   'related_word': 'Q96758092',
#   'related_word_label': 'type of regulation and control'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P1889',
#   'related_word': 'Q417861',
#   'related_word_label': 'Control'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P1889',
#   'related_word': 'Q16033323',
#   'related_word_label': 'Controle'},
#  {'word': 'Q338754',
#   'word_label': 'control',
#   'relation': 'P1889',
#   'related_word': 'Q67204819',
#   'related_word_label': 'Kontrol'},
#  {'word': 'Q500256',
#   'word_label': 'chemical structure',
#   'relation': 'P31',
#   'related_word': 'Q111972893',
#   'related_word_label': 'type of structure'},
#  {'word': 'Q500256',
#   'word_label': 'chemical structure',
#   'relation': 'P279',
#   'related_word': 'Q6671777',
#   'related_word_label': 'structure'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P31',
#   'related_word': 'Q1969448',
#   'related_word_label': 'term'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P31',
#   'related_word': 'Q1969448',
#   'related_word_label': 'term'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P31',
#   'related_word': 'Q1969448',
#   'related_word_label': 'term'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P31',
#   'related_word': 'Q1969448',
#   'related_word_label': 'term'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P1889',
#   'related_word': 'Q55605484',
#   'related_word_label': 'bioelectricity'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P1889',
#   'related_word': 'Q55605484',
#   'related_word_label': 'bioelectricity'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P1889',
#   'related_word': 'Q55605484',
#   'related_word_label': 'bioelectricity'},
#  {'word': 'Q644240',
#   'word_label': 'biosignal',
#   'relation': 'P1889',
#   'related_word': 'Q55605484',
#   'related_word_label': 'bioelectricity'},
#  {'word': 'Q693457',
#   'word_label': 'alpha compositing',
#   'relation': 'P279',
#   'related_word': 'Q7600677',
#   'related_word_label': 'computer graphics'},
#  {'word': 'Q736777',
#   'word_label': 'calibration',
#   'relation': 'P31',
#   'related_word': 'Q151885',
#   'related_word_label': 'concept'},
#  {'word': 'Q736777',
#   'word_label': 'calibration',
#   'relation': 'P279',
#   'related_word': 'Q1714153',
#   'related_word_label': 'adjustment'},
#  {'word': 'Q736777',
#   'word_label': 'calibration',
#   'relation': 'P279',
#   'related_word': 'Q104637332',
#   'related_word_label': 'planned process'},
#  {'word': 'Q736777',
#   'word_label': 'calibration',
#   'relation': 'P1889',
#   'related_word': 'Q212424',
#   'related_word_label': 'official verification'},
#  {'word': 'Q736777',
#   'word_label': 'calibration',
#   'relation': 'P1889',
#   'related_word': 'Q110975404',
#   'related_word_label': 'adjustment of a measuring system'},
#  {'word': 'Q758901',
#   'word_label': 'audiovisual',
#   'relation': 'P31',
#   'related_word': 'Q1969448',
#   'related_word_label': 'term'},
#  {'word': 'Q758901',
#   'word_label': 'audiovisual',
#   'relation': 'P31',
#   'related_word': 'Q58901077',
#   'related_word_label': 'publication format'},
#  {'word': 'Q758901',
#   'word_label': 'audiovisual',
#   'relation': 'P279',
#   'related_word': 'Q1209283',
#   'related_word_label': 'electronic media'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P31',
#   'related_word': 'Q1047113',
#   'related_word_label': 'field of study'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P31',
#   'related_word': 'Q2267705',
#   'related_word_label': 'field of study'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P279',
#   'related_word': 'Q180160',
#   'related_word_label': 'metadata'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P279',
#   'related_word': 'Q386724',
#   'related_word_label': 'work'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P361',
#   'related_word': 'Q4769616',
#   'related_word_label': 'annotated bibliography'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P1889',
#   'related_word': 'Q333291',
#   'related_word_label': 'abstract'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P1889',
#   'related_word': 'Q1141900',
#   'related_word_label': 'unstructured data'},
#  {'word': 'Q857525',
#   'word_label': 'annotation',
#   'relation': 'P1889',
#   'related_word': 'Q12823770',
#   'related_word_label': 'note'},
#  {'word': 'Q864212',
#   'word_label': 'bioassay',
#   'relation': 'P279',
#   'related_word': 'Q739897',
#   'related_word_label': 'assay'},
#  {'word': 'Q864212',
#   'word_label': 'bioassay',
#   'relation': 'P279',
#   'related_word': 'Q3247516',
#   'related_word_label': 'lab technique'},
#  {'word': 'Q864574',
#   'word_label': 'biomarker',
#   'relation': 'P279',
#   'related_word': 'Q2393187',
#   'related_word_label': 'molecular entity'},
#  {'word': 'Q864574',
#   'word_label': 'biomarker',
#   'relation': 'P279',
#   'related_word': 'Q18208034',
#   'related_word_label': 'indicator'},
#  {'word': 'Q864574',
#   'word_label': 'biomarker',
#   'relation': 'P361',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q864574',
#   'word_label': 'biomarker',
#   'relation': 'P1889',
#   'related_word': 'Q359232',
#   'related_word_label': 'Marker'},
#  {'word': 'Q868299',
#   'word_label': 'control flow',
#   'relation': 'P279',
#   'related_word': 'Q124590',
#   'related_word_label': 'program code'},
#  {'word': 'Q868299',
#   'word_label': 'control flow',
#   'relation': 'P279',
#   'related_word': 'Q6671777',
#   'related_word_label': 'structure'},
#  {'word': 'Q1172540',
#   'word_label': 'data stream',
#   'relation': 'P279',
#   'related_word': 'Q20937557',
#   'related_word_label': 'sequence'},
#  {'word': 'Q1172540',
#   'word_label': 'data stream',
#   'relation': 'P527',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q1434060',
#   'word_label': 'bounding volume',
#   'relation': 'P31',
#   'related_word': 'Q66755638',
#   'related_word_label': 'computer graphics term'},
#  {'word': 'Q1643805',
#   'word_label': 'container',
#   'relation': 'P31',
#   'related_word': 'Q827335',
#   'related_word_label': 'abstract data type'},
#  {'word': 'Q1643805',
#   'word_label': 'container',
#   'relation': 'P279',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q1643805',
#   'word_label': 'container',
#   'relation': 'P279',
#   'related_word': 'Q99527517',
#   'related_word_label': 'collective entity'},
#  {'word': 'Q1643805',
#   'word_label': 'container',
#   'relation': 'P460',
#   'related_word': 'Q17008256',
#   'related_word_label': 'collection'},
#  {'word': 'Q1643805',
#   'word_label': 'container',
#   'relation': 'P1889',
#   'related_word': 'Q167772',
#   'related_word_label': 'digital container format'},
#  {'word': 'Q1866689',
#   'word_label': 'configuration',
#   'relation': 'P279',
#   'related_word': 'Q246672',
#   'related_word_label': 'mathematical object'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P31',
#   'related_word': 'Q116505632',
#   'related_word_label': 'type of process'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P279',
#   'related_word': 'Q3249551',
#   'related_word_label': 'process'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P527',
#   'related_word': 'Q52948',
#   'related_word_label': 'interaction'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P527',
#   'related_word': 'Q4026292',
#   'related_word_label': 'action'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P1552',
#   'related_word': 'Q2199864',
#   'related_word_label': 'duration'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P1552',
#   'related_word': 'Q114403556',
#   'related_word_label': 'divisibility'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P1552',
#   'related_word': 'Q125542526',
#   'related_word_label': 'type of activity'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P1889',
#   'related_word': 'Q192581',
#   'related_word_label': 'job activity'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P1889',
#   'related_word': 'Q3249551',
#   'related_word_label': 'process'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1552',
#   'related_word': 'Q1783819',
#   'related_word_label': 'coordinate axis'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q3250736',
#   'related_word_label': 'coordinate'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q3250736',
#   'related_word_label': 'coordinate'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q3250736',
#   'related_word_label': 'coordinate'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q3250736',
#   'related_word_label': 'coordinate'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q4291876',
#   'related_word_label': 'Q4291876'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q4291876',
#   'related_word_label': 'Q4291876'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q4291876',
#   'related_word_label': 'Q4291876'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P1889',
#   'related_word': 'Q4291876',
#   'related_word_label': 'Q4291876'},
#  {'word': 'Q11210',
#   'word_label': 'coordinate system',
#   'relation': 'P2670',
#   'related_word': 'Q3250736',
#   'related_word_label': 'coordinate'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P1889',
#   'related_word': 'Q4026292',
#   'related_word_label': 'action'},
#  {'word': 'Q1914636',
#   'word_label': 'activity',
#   'relation': 'P1889',
#   'related_word': 'Q12737077',
#   'related_word_label': 'occupation'},
#  {'word': 'Q2285707',
#   'word_label': 'categorical variable',
#   'relation': 'P31',
#   'related_word': 'Q7604387',
#   'related_word_label': 'statistical data type'},
#  {'word': 'Q2285707',
#   'word_label': 'categorical variable',
#   'relation': 'P279',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q2285707',
#   'word_label': 'categorical variable',
#   'relation': 'P279',
#   'related_word': 'Q50701',
#   'related_word_label': 'variable'},
#  {'word': 'Q2285707',
#   'word_label': 'categorical variable',
#   'relation': 'P460',
#   'related_word': 'Q760170',
#   'related_word_label': 'enumerated type'},
#  {'word': 'Q2634111',
#   'word_label': 'Action',
#   'relation': 'P31',
#   'related_word': 'Q4830453',
#   'related_word_label': 'business'},
#  {'word': 'Q2634111',
#   'word_label': 'Action',
#   'relation': 'P31',
#   'related_word': 'Q6881511',
#   'related_word_label': 'enterprise'},
#  {'word': 'Q2634111',
#   'word_label': 'Action',
#   'relation': 'P31',
#   'related_word': 'Q108255949',
#   'related_word_label': 'variety store chain'},
#  {'word': 'Q2933935',
#   'word_label': 'camera resectioning',
#   'relation': 'P31',
#   'related_word': 'Q2695280',
#   'related_word_label': 'technique'},
#  {'word': 'Q2933935',
#   'word_label': 'camera resectioning',
#   'relation': 'P31',
#   'related_word': 'Q4220920',
#   'related_word_label': 'filmmaking occupation'},
#  {'word': 'Q3500685',
#   'word_label': 'audio',
#   'relation': 'P31',
#   'related_word': 'Q94102244',
#   'related_word_label': 'flow element'},
#  {'word': 'Q3500685',
#   'word_label': 'audio',
#   'relation': 'P31',
#   'related_word': 'Q94102316',
#   'related_word_label': 'phrasing element'},
#  {'word': 'Q3500685',
#   'word_label': 'audio',
#   'relation': 'P31',
#   'related_word': 'Q94102319',
#   'related_word_label': 'embedded element'},
#  {'word': 'Q3500685',
#   'word_label': 'audio',
#   'relation': 'P31',
#   'related_word': 'Q94102323',
#   'related_word_label': 'interactive element'},
#  {'word': 'Q3500685',
#   'word_label': 'audio',
#   'relation': 'P31',
#   'related_word': 'Q94102326',
#   'related_word_label': 'palpable element'},
#  {'word': 'Q3500685',
#   'word_label': 'audio',
#   'relation': 'P527',
#   'related_word': 'Q94100367',
#   'related_word_label': 'source'},
#  {'word': 'Q3500685',
#   'word_label': 'audio',
#   'relation': 'P527',
#   'related_word': 'Q94100374',
#   'related_word_label': 'track'},
#  {'word': 'Q3859833',
#   'word_label': '3D model',
#   'relation': 'P279',
#   'related_word': 'Q1979154',
#   'related_word_label': 'model'},
#  {'word': 'Q3859833',
#   'word_label': '3D model',
#   'relation': 'P279',
#   'related_word': 'Q119228987',
#   'related_word_label': 'media object'},
#  {'word': 'Q3859833',
#   'word_label': '3D model',
#   'relation': 'P1269',
#   'related_word': 'Q568742',
#   'related_word_label': '3D modeling'},
#  {'word': 'Q4913864',
#   'word_label': 'Binary',
#   'relation': 'P31',
#   'related_word': 'Q7725634',
#   'related_word_label': 'literary work'},
#  {'word': 'Q5227290',
#   'word_label': 'data file',
#   'relation': 'P279',
#   'related_word': 'Q82753',
#   'related_word_label': 'computer file'},
#  {'word': 'Q5651824',
#   'word_label': '2D',
#   'relation': 'P31',
#   'related_word': 'Q5',
#   'related_word_label': 'human'},
#  {'word': 'Q5651824',
#   'word_label': '2D',
#   'relation': 'P31',
#   'related_word': 'Q215380',
#   'related_word_label': 'musical group'},
#  {'word': 'Q5651824',
#   'word_label': '2D',
#   'relation': 'P527',
#   'related_word': 'Q5801203',
#   'related_word_label': 'Deddy Dhukun'},
#  {'word': 'Q5651824',
#   'word_label': '2D',
#   'relation': 'P1889',
#   'related_word': 'Q29023',
#   'related_word_label': '2D'},
#  {'word': 'Q16860308',
#   'word_label': 'Box',
#   'relation': 'P31',
#   'related_word': 'Q101352',
#   'related_word_label': 'family name'},
#  {'word': 'Q16860308',
#   'word_label': 'Box',
#   'relation': 'P1889',
#   'related_word': 'Q227380',
#   'related_word_label': 'Box'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P31',
#   'related_word': 'Q151885',
#   'related_word_label': 'concept'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P31',
#   'related_word': 'Q1047113',
#   'related_word_label': 'field of study'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P31',
#   'related_word': 'Q2267705',
#   'related_word_label': 'field of study'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P279',
#   'related_word': 'Q8513',
#   'related_word_label': 'database'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P279',
#   'related_word': 'Q27948',
#   'related_word_label': 'list'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P279',
#   'related_word': 'Q175263',
#   'related_word_label': 'data structure'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P279',
#   'related_word': 'Q339678',
#   'related_word_label': 'distributed data storage'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P279',
#   'related_word': 'Q15836568',
#   'related_word_label': 'computer network protocol'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P279',
#   'related_word': 'Q25110971',
#   'related_word_label': 'distributed ledger'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P527',
#   'related_word': 'Q104886715',
#   'related_word_label': 'block'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P1552',
#   'related_word': 'Q477202',
#   'related_word_label': 'cryptographic hash function'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P1552',
#   'related_word': 'Q2994424',
#   'related_word_label': 'consensus'},
#  {'word': 'Q20514253',
#   'word_label': 'blockchain',
#   'relation': 'P1889',
#   'related_word': 'Q15960875',
#   'related_word_label': 'Blockchain.com'},
#  {'word': 'Q20685814',
#   'word_label': '4D',
#   'relation': 'P31',
#   'related_word': 'Q482994',
#   'related_word_label': 'album'},
#  {'word': 'Q20685814',
#   'word_label': '4D',
#   'relation': 'P361',
#   'related_word': 'Q100736927',
#   'related_word_label': "Matthew Shipp's albums in chronological order"},
#  {'word': 'Q20685814',
#   'word_label': '4D',
#   'relation': 'P1889',
#   'related_word': 'Q238112',
#   'related_word_label': '4D'},
#  {'word': 'Q37141227',
#   'word_label': 'Code',
#   'relation': 'P31',
#   'related_word': 'Q101352',
#   'related_word_label': 'family name'},
#  {'word': 'Q37141227',
#   'word_label': 'Code',
#   'relation': 'P1889',
#   'related_word': 'Q5013277',
#   'related_word_label': 'CODE'},
#  {'word': 'Q37141227',
#   'word_label': 'Code',
#   'relation': 'P1889',
#   'related_word': 'Q125914664',
#   'related_word_label': 'Code'},
#  {'word': 'Q56291707',
#   'word_label': 'Common Workflow Language',
#   'relation': 'P31',
#   'related_word': 'Q43229',
#   'related_word_label': 'organization'},
#  {'word': 'Q56291707',
#   'word_label': 'Common Workflow Language',
#   'relation': 'P31',
#   'related_word': 'Q177634',
#   'related_word_label': 'community'},
#  {'word': 'Q56291707',
#   'word_label': 'Common Workflow Language',
#   'relation': 'P31',
#   'related_word': 'Q235557',
#   'related_word_label': 'file format'},
#  {'word': 'Q56291707',
#   'word_label': 'Common Workflow Language',
#   'relation': 'P31',
#   'related_word': 'Q681263',
#   'related_word_label': 'clóset standard'},
#  {'word': 'Q56291707',
#   'word_label': 'Common Workflow Language',
#   'relation': 'P31',
#   'related_word': 'Q105695317',
#   'related_word_label': 'workflow language'},
#  {'word': 'Q65311416',
#   'word_label': 'analytic',
#   'relation': 'P31',
#   'related_word': 'Q937228',
#   'related_word_label': 'property'},
#  {'word': 'Q65311416',
#   'word_label': 'analytic',
#   'relation': 'P279',
#   'related_word': 'Q25583046',
#   'related_word_label': 'typological classification'},
#  {'word': 'Q65311416',
#   'word_label': 'analytic',
#   'relation': 'P361',
#   'related_word': 'Q61014757',
#   'related_word_label': 'analytic and synthetic'},
#  {'word': 'Q65311416',
#   'word_label': 'analytic',
#   'relation': 'P1889',
#   'related_word': 'Q12301326',
#   'related_word_label': 'analytic statement'},
#  {'word': 'Q94701573',
#   'word_label': '3D scanning',
#   'relation': 'P31',
#   'related_word': 'Q2695280',
#   'related_word_label': 'technique'},
#  {'word': 'Q94701573',
#   'word_label': '3D scanning',
#   'relation': 'P279',
#   'related_word': 'Q11873863',
#   'related_word_label': 'scanning'},
#  {'word': 'Q96797376',
#   'word_label': 'biosample',
#   'relation': 'P279',
#   'related_word': 'Q49906',
#   'related_word_label': 'sample'},
#  {'word': 'Q96797376',
#   'word_label': 'biosample',
#   'relation': 'P279',
#   'related_word': 'Q485146',
#   'related_word_label': 'sample'},
#  {'word': 'Q108276326',
#   'word_label': '3D',
#   'relation': 'P31',
#   'related_word': 'Q685935',
#   'related_word_label': 'trade magazine'},
#  {'word': 'Q124892534',
#   'word_label': 'Biochemical',
#   'relation': 'P31',
#   'related_word': 'Q105543609',
#   'related_word_label': 'musical work/composition'},
#  {'word': 'Q1071',
#   'word_label': 'geography',
#   'relation': 'P31',
#   'related_word': 'Q2465832',
#   'related_word_label': 'branch of science'},
#  {'word': 'Q1071',
#   'word_label': 'geography',
#   'relation': 'P31',
#   'related_word': 'Q4671286',
#   'related_word_label': 'academic major'},
#  {'word': 'Q1071',
#   'word_label': 'geography',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q1071',
#   'word_label': 'geography',
#   'relation': 'P1889',
#   'related_word': 'Q1069',
#   'related_word_label': 'geology'},
#  {'word': 'Q1071',
#   'word_label': 'geography',
#   'relation': 'P1889',
#   'related_word': 'Q1194350',
#   'related_word_label': 'Geography'},
#  {'word': 'Q7162',
#   'word_label': 'genetics',
#   'relation': 'P31',
#   'related_word': 'Q336',
#   'related_word_label': 'science'},
#  {'word': 'Q7162',
#   'word_label': 'genetics',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q7162',
#   'word_label': 'genetics',
#   'relation': 'P31',
#   'related_word': 'Q28598684',
#   'related_word_label': 'branch of biology'},
#  {'word': 'Q7162',
#   'word_label': 'genetics',
#   'relation': 'P279',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q7162',
#   'word_label': 'genetics',
#   'relation': 'P361',
#   'related_word': 'Q420',
#   'related_word_label': 'biology'},
#  {'word': 'Q7162',
#   'word_label': 'genetics',
#   'relation': 'P460',
#   'related_word': 'Q3243680',
#   'related_word_label': 'introduction to genetics'},
#  {'word': 'Q7162',
#   'word_label': 'genetics',
#   'relation': 'P1889',
#   'related_word': 'Q3508604',
#   'related_word_label': 'genology'},
#  {'word': 'Q8087',
#   'word_label': 'geometry',
#   'relation': 'P31',
#   'related_word': 'Q1936384',
#   'related_word_label': 'area of mathematics'},
#  {'word': 'Q8087',
#   'word_label': 'geometry',
#   'relation': 'P279',
#   'related_word': 'Q395',
#   'related_word_label': 'mathematics'},
#  {'word': 'Q8087',
#   'word_label': 'geometry',
#   'relation': 'P361',
#   'related_word': 'Q395',
#   'related_word_label': 'mathematics'},
#  {'word': 'Q8087',
#   'word_label': 'geometry',
#   'relation': 'P1889',
#   'related_word': 'Q207961',
#   'related_word_label': 'shape'},
#  {'word': 'Q8087',
#   'word_label': 'geometry',
#   'relation': 'P1889',
#   'related_word': 'Q210113',
#   'related_word_label': 'La Géométrie'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P31',
#   'related_word': 'Q63981612',
#   'related_word_label': 'product category'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P279',
#   'related_word': 'Q17538258',
#   'related_word_label': 'recreative work'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P361',
#   'related_word': 'Q11042',
#   'related_word_label': 'culture'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P361',
#   'related_word': 'Q66662493',
#   'related_word_label': 'sport, games, physical exercises'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P527',
#   'related_word': 'Q1151067',
#   'related_word_label': 'rule'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P527',
#   'related_word': 'Q4197743',
#   'related_word_label': 'player'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P1889',
#   'related_word': 'Q7889',
#   'related_word_label': 'video game'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P1889',
#   'related_word': 'Q1150958',
#   'related_word_label': 'playing'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P1889',
#   'related_word': 'Q1493033',
#   'related_word_label': 'Game'},
#  {'word': 'Q11410',
#   'word_label': 'game',
#   'relation': 'P1889',
#   'related_word': 'Q15079592',
#   'related_word_label': 'strategic game'},
#  {'word': 'Q26939',
#   'word_label': 'epigenetics',
#   'relation': 'P31',
#   'related_word': 'Q28598684',
#   'related_word_label': 'branch of biology'},
#  {'word': 'Q26939',
#   'word_label': 'epigenetics',
#   'relation': 'P279',
#   'related_word': 'Q7162',
#   'related_word_label': 'genetics'},
#  {'word': 'Q26939',
#   'word_label': 'epigenetics',
#   'relation': 'P361',
#   'related_word': 'Q7162',
#   'related_word_label': 'genetics'},
#  {'word': 'Q26939',
#   'word_label': 'epigenetics',
#   'relation': 'P527',
#   'related_word': 'Q3589153',
#   'related_word_label': 'epigenomics'},
#  {'word': 'Q26939',
#   'word_label': 'epigenetics',
#   'relation': 'P1269',
#   'related_word': 'Q411391',
#   'related_word_label': 'regulation of gene expression'},
#  {'word': 'Q37732',
#   'word_label': 'demography',
#   'relation': 'P31',
#   'related_word': 'Q4671286',
#   'related_word_label': 'academic major'},
#  {'word': 'Q37732',
#   'word_label': 'demography',
#   'relation': 'P31',
#   'related_word': 'Q11862829',
#   'related_word_label': 'academic discipline'},
#  {'word': 'Q37732',
#   'word_label': 'demography',
#   'relation': 'P279',
#   'related_word': 'Q1071',
#   'related_word_label': 'geography'},
#  {'word': 'Q37732',
#   'word_label': 'demography',
#   'relation': 'P279',
#   'related_word': 'Q34749',
#   'related_word_label': 'social science'},
#  {'word': 'Q37732',
#   'word_label': 'demography',
#   'relation': 'P1889',
#   'related_word': 'Q2725376',
#   'related_word_label': 'demographics'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P279',
#   'related_word': 'Q286583',
#   'related_word_label': 'manifestation'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P279',
#   'related_word': 'Q15621286',
#   'related_word_label': 'intellectual work'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P279',
#   'related_word': 'Q37866906',
#   'related_word_label': 'information resource'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P527',
#   'related_word': 'Q340169',
#   'related_word_label': 'media'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P527',
#   'related_word': 'Q3529597',
#   'related_word_label': 'heading'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P527',
#   'related_word': 'Q59157099',
#   'related_word_label': 'document-type information'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P1552',
#   'related_word': 'Q107478770',
#   'related_word_label': 'document genre'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P1889',
#   'related_word': 'Q11853106',
#   'related_word_label': 'document'},
#  {'word': 'Q49848',
#   'word_label': 'document',
#   'relation': 'P1889',
#   'related_word': 'Q107435521',
#   'related_word_label': 'record'},
#  {'word': 'Q56933',
#   'word_label': 'image segmentation',
#   'relation': 'P31',
#   'related_word': 'Q3182649',
#   'related_word_label': 'separation'},
#  {'word': 'Q56933',
#   'word_label': 'image segmentation',
#   'relation': 'P279',
#   'related_word': 'Q844240',
#   'related_word_label': 'computer vision'},
#  {'word': 'Q56933',
#   'word_label': 'image segmentation',
#   'relation': 'P1269',
#   'related_word': 'Q1070689',
#   'related_word_label': 'digital image processing'},
#  {'word': 'Q79785',
#   'word_label': 'electrocardiography',
#   'relation': 'P31',
#   'related_word': 'Q55215251',
#   'related_word_label': 'medical test type'},
#  {'word': 'Q79785',
#   'word_label': 'electrocardiography',
#   'relation': 'P279',
#   'related_word': 'Q2671652',
#   'related_word_label': 'medical test'},
#  {'word': 'Q79785',
#   'word_label': 'electrocardiography',
#   'relation': 'P279',
#   'related_word': 'Q5038709',
#   'related_word_label': 'diagnostic test in cardiology'},
#  {'word': 'Q79785',
#   'word_label': 'electrocardiography',
#   'relation': 'P279',
#   'related_word': 'Q13557414',
#   'related_word_label': 'recording'},
#  {'word': 'Q79785',
#   'word_label': 'electrocardiography',
#   'relation': 'P361',
#   'related_word': 'Q1154774',
#   'related_word_label': 'electrophysiology'},
#  {'word': 'Q104934',
#   'word_label': 'fundamental interaction',
#   'relation': 'P31',
#   'related_word': 'Q123345464',
#   'related_word_label': 'type of interaction'},
#  {'word': 'Q104934',
#   'word_label': 'fundamental interaction',
#   'relation': 'P279',
#   'related_word': 'Q52948',
#   'related_word_label': 'interaction'},
#  {'word': 'Q104934',
#   'word_label': 'fundamental interaction',
#   'relation': 'P279',
#   'related_word': 'Q1293220',
#   'related_word_label': 'physical phenomenon'},
#  {'word': 'Q104934',
#   'word_label': 'fundamental interaction',
#   'relation': 'P527',
#   'related_word': 'Q11412',
#   'related_word_label': 'gravity'},
#  {'word': 'Q104934',
#   'word_label': 'fundamental interaction',
# ...
#   'related_word_label': 'social networking service'},
#  {'word': 'Q2715623',
#   'word_label': 'social network',
#   'relation': 'P1889',
#   'related_word': 'Q19368491',
#   'related_word_label': 'social networking'},
#  {'word': 'Q2995644',
#   'word_label': 'result',
#   'relation': 'P279',
#   'related_word': 'Q35120',
#   'related_word_label': 'entity'},
#  {'word': 'Q2995644',
#   'word_label': 'result',
#   'relation': 'P460',
#   'related_word': 'Q926230',
#   'related_word_label': 'effect'},
#  {'word': 'Q2995644',
#   'word_label': 'result',
#   'relation': 'P1269',
#   'related_word': 'Q179289',
#   'related_word_label': 'causality'},
#  {'word': 'Q2995644',
#   'word_label': 'result',
#   'relation': 'P1889',
#   'related_word': 'Q261155',
#   'related_word_label': 'consequent'},
#  {'word': 'Q2995644',
#   'word_label': 'result',
#   'relation': 'P1889',
#   'related_word': 'Q733541',
#   'related_word_label': 'consequence'},
#  {'word': 'Q2995644',
#   'word_label': 'result',
#   'relation': 'P1889',
#   'related_word': 'Q4503831',
#   'related_word_label': 'goal'},
#  {'word': 'Q3396184',
#   'word_label': 'radio frequency',
#   'relation': 'P279',
#   'related_word': 'Q4262',
#   'related_word_label': 'radio wave'},
#  {'word': 'Q3396184',
#   'word_label': 'radio frequency',
#   'relation': 'P279',
#   'related_word': 'Q11652',
#   'related_word_label': 'frequency'},
#  {'word': 'Q3396184',
#   'word_label': 'radio frequency',
#   'relation': 'P1889',
#   'related_word': 'Q575784',
#   'related_word_label': 'baseband'},
#  {'word': 'Q3691017',
#   'word_label': 'script',
#   'relation': 'P31',
#   'related_word': 'Q223393',
#   'related_word_label': 'literary genre'},
#  {'word': 'Q3691017',
#   'word_label': 'script',
#   'relation': 'P279',
#   'related_word': 'Q121536501',
#   'related_word_label': 'script'},
#  {'word': 'Q3691017',
#   'word_label': 'script',
#   'relation': 'P361',
#   'related_word': 'Q11424',
#   'related_word_label': 'film'},
#  {'word': 'Q3691017',
#   'word_label': 'script',
#   'relation': 'P361',
#   'related_word': 'Q25379',
#   'related_word_label': 'play'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P31',
#   'related_word': 'Q2135465',
#   'related_word_label': 'legal concept'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P279',
#   'related_word': 'Q37787614',
#   'related_word_label': 'person property'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P279',
#   'related_word': 'Q61151961',
#   'related_word_label': 'individual data'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P1269',
#   'related_word': 'Q78908682',
#   'related_word_label': 'security risk'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P1269',
#   'related_word': 'Q122764215',
#   'related_word_label': 'personal risk'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P1889',
#   'related_word': 'Q1076693',
#   'related_word_label': 'personally identifiable information'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P1889',
#   'related_word': 'Q2996679',
#   'related_word_label': 'contact information'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P1889',
#   'related_word': 'Q59157079',
#   'related_word_label': 'biographic information'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P2670',
#   'related_word': 'Q32090',
#   'related_word_label': 'lifestyle'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P2670',
#   'related_word': 'Q188952',
#   'related_word_label': 'medical history'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P2670',
#   'related_word': 'Q192907',
#   'related_word_label': 'financial statement'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P2670',
#   'related_word': 'Q1076693',
#   'related_word_label': 'personally identifiable information'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P2670',
#   'related_word': 'Q2628882',
#   'related_word_label': 'legal status'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P2670',
#   'related_word': 'Q18745135',
#   'related_word_label': 'health data'},
#  {'word': 'Q3702971',
#   'word_label': 'personal data',
#   'relation': 'P2670',
#   'related_word': 'aa3d3bf3bce1685df5bcbbeaa61e4a4a',
#   'related_word_label': 'http://www.wikidata.org/.well-known/genid/aa3d3bf3bce1685df5bcbbeaa61e4a4a'},
#  {'word': 'Q5078274',
#   'word_label': 'sketch',
#   'relation': 'P279',
#   'related_word': 'Q93184',
#   'related_word_label': 'drawing'},
#  {'word': 'Q5078274',
#   'word_label': 'sketch',
#   'relation': 'P279',
#   'related_word': 'Q1884048',
#   'related_word_label': 'underpainting'},
#  {'word': 'Q5078274',
#   'word_label': 'sketch',
#   'relation': 'P1889',
#   'related_word': 'Q55760865',
#   'related_word_label': 'sketch'},
#  {'word': 'Q5078274',
#   'word_label': 'sketch',
#   'relation': 'P1889',
#   'related_word': 'Q115801874',
#   'related_word_label': 'design drawing'},
#  {'word': 'Q5078274',
#   'word_label': 'sketch',
#   'relation': 'P1889',
#   'related_word': 'Q125510604',
#   'related_word_label': 'Esquisse'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P279',
#   'related_word': 'Q99527517',
#   'related_word_label': 'collective entity'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P361',
#   'related_word': 'Q58778',
#   'related_word_label': 'system'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P527',
#   'related_word': 'Q61964189',
#   'related_word_label': 'structural component'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1269',
#   'related_word': 'Q17014966',
#   'related_word_label': 'Function-Behaviour-Structure ontology'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q215772',
#   'related_word_label': 'emergence'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q2083958',
#   'related_word_label': 'pattern'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q4849953',
#   'related_word_label': 'balance'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q11061286',
#   'related_word_label': 'equilibrium'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q11398090',
#   'related_word_label': 'creation'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q12893838',
#   'related_word_label': 'order'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q66424847',
#   'related_word_label': 'spatial arrangement'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1552',
#   'related_word': 'Q111972893',
#   'related_word_label': 'type of structure'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1889',
#   'related_word': 'Q811979',
#   'related_word_label': 'architectural structure'},
#  {'word': 'Q6671777',
#   'word_label': 'structure',
#   'relation': 'P1889',
#   'related_word': 'Q8083174',
#   'related_word_label': 'structure'},
#  {'word': 'Q7239673',
#   'word_label': 'predictive modelling',
#   'relation': 'P279',
#   'related_word': 'Q1116876',
#   'related_word_label': 'scientific modeling'},
#  {'word': 'Q7239673',
#   'word_label': 'predictive modelling',
#   'relation': 'P1269',
#   'related_word': 'Q2374463',
#   'related_word_label': 'data science'},
#  {'word': 'Q9067355',
#   'word_label': 'spiking neural network',
#   'relation': 'P31',
#   'related_word': 'Q28058114',
#   'related_word_label': 'data clustering algorithm'},
#  {'word': 'Q9067355',
#   'word_label': 'spiking neural network',
#   'relation': 'P279',
#   'related_word': 'Q192776',
#   'related_word_label': 'artificial neural network'},
#  {'word': 'Q11692743',
#   'word_label': 'spatial data',
#   'relation': 'P279',
#   'related_word': 'Q124472412',
#   'related_word_label': 'geodata'},
#  {'word': 'Q15753091',
#   'word_label': 'Respiration',
#   'relation': 'P31',
#   'related_word': 'Q5633421',
#   'related_word_label': 'scientific journal'},
#  {'word': 'Q15753091',
#   'word_label': 'Respiration',
#   'relation': 'P31',
#   'related_word': 'Q5953270',
#   'related_word_label': 'hybrid open access journal'},
#  {'word': 'Q19718090',
#   'word_label': 'Signal',
#   'relation': 'P31',
#   'related_word': 'Q341',
#   'related_word_label': 'free software'},
#  {'word': 'Q19718090',
#   'word_label': 'Signal',
#   'relation': 'P31',
#   'related_word': 'Q35127',
#   'related_word_label': 'website'},
#  {'word': 'Q19718090',
#   'word_label': 'Signal',
#   'relation': 'P31',
#   'related_word': 'Q620615',
#   'related_word_label': 'mobile app'},
#  {'word': 'Q19718090',
#   'word_label': 'Signal',
#   'relation': 'P31',
#   'related_word': 'Q2462003',
#   'related_word_label': 'instant messaging client'},
#  {'word': 'Q19718090',
#   'word_label': 'Signal',
#   'relation': 'P31',
#   'related_word': 'Q5375622',
#   'related_word_label': 'encryption software'},
#  {'word': 'Q19718090',
#   'word_label': 'Signal',
#   'relation': 'P31',
#   'related_word': 'Q18922759',
#   'related_word_label': 'messaging app'},
#  {'word': 'Q19718090',
#   'word_label': 'Signal',
#   'relation': 'P527',
#   'related_word': 'Q27031176',
#   'related_word_label': 'Signal Protocol'},
#  {'word': 'Q20937557',
#   'word_label': 'sequence',
#   'relation': 'P279',
#   'related_word': 'Q16889133',
#   'related_word_label': 'class'},
#  {'word': 'Q20937557',
#   'word_label': 'sequence',
#   'relation': 'P1552',
#   'related_word': 'Q4049983',
#   'related_word_label': 'cardinality'},
#  {'word': 'Q20937557',
#   'word_label': 'sequence',
#   'relation': 'P1889',
#   'related_word': 'Q133250',
#   'related_word_label': 'sequence'},
#  {'word': 'Q20937557',
#   'word_label': 'sequence',
#   'relation': 'P1889',
#   'related_word': 'Q170198',
#   'related_word_label': 'series'},
#  {'word': 'Q20937557',
#   'word_label': 'sequence',
#   'relation': 'P1889',
#   'related_word': 'Q600590',
#   'related_word_label': '𝑛-tuple'},
#  {'word': 'Q20937557',
#   'word_label': 'sequence',
#   'relation': 'P1889',
#   'related_word': 'Q16887380',
#   'related_word_label': 'group'},
#  {'word': 'Q37169573',
#   'word_label': 'Radio',
#   'relation': 'P31',
#   'related_word': 'Q101352',
#   'related_word_label': 'family name'},
#  {'word': 'Q37169573',
#   'word_label': 'Radio',
#   'relation': 'P1889',
#   'related_word': 'Q224366',
#   'related_word_label': 'Radio'},
#  {'word': 'Q37453697',
#   'word_label': 'Sensor',
#   'relation': 'P31',
#   'related_word': 'Q101352',
#   'related_word_label': 'family name'},
#  {'word': 'Q37453697',
#   'word_label': 'Sensor',
#   'relation': 'P1889',
#   'related_word': 'Q1211234',
#   'related_word_label': 'Sensor'},
#  {'word': 'Q55631277',
#   'word_label': 'Real world data',
#   'relation': 'P279',
#   'related_word': 'Q42848',
#   'related_word_label': 'data'},
#  {'word': 'Q66043426',
#   'word_label': 'Raster',
#   'relation': 'P31',
#   'related_word': 'Q18127',
#   'related_word_label': 'record label'},
#  {'word': 'Q121463492',
#   'word_label': 'Polarisation',
#   'relation': 'P31',
#   'related_word': 'Q3305213',
#   'related_word_label': 'painting'},
#  {'word': 'Q130556645',
#   'word_label': 'SPECTRA',
#   'relation': 'P31',
#   'related_word': 'Q4830453',
#   'related_word_label': 'business'},
#  {'word': 'Q130556645',
#   'word_label': 'SPECTRA',
#   'relation': 'P31',
#   'related_word': 'Q6881511',
#   'related_word_label': 'enterprise'},
#  {'word': 'Q14748',
#   'word_label': 'table',
#   'relation': 'P279',
#   'related_word': 'Q14745',
#   'related_word_label': 'furniture'},
#  {'word': 'Q14748',
#   'word_label': 'table',
#   'relation': 'P527',
#   'related_word': 'Q56056049',
#   'related_word_label': 'furniture leg'},
#  {'word': 'Q14748',
#   'word_label': 'table',
#   'relation': 'P1889',
#   'related_word': 'Q14749',
#   'related_word_label': 'Table'},
#  {'word': 'Q14748',
#   'word_label': 'table',
#   'relation': 'P1889',
#   'related_word': 'Q496946',
#   'related_word_label': 'table'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P31',
#   'related_word': 'Q317623',
#   'related_word_label': 'technical standard'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P279',
#   'related_word': 'Q61694',
#   'related_word_label': 'Uniform Resource Identifier'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P460',
#   'related_word': 'Q61694',
#   'related_word_label': 'Uniform Resource Identifier'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P1889',
#   'related_word': 'Q11135',
#   'related_word_label': 'IP address'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P1889',
#   'related_word': 'Q61694',
#   'related_word_label': 'Uniform Resource Identifier'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P1889',
#   'related_word': 'Q76497',
#   'related_word_label': 'URN'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P1889',
#   'related_word': 'Q440611',
#   'related_word_label': 'URL'},
#  {'word': 'Q42253',
#   'word_label': 'URL',
#   'relation': 'P1889',
#   'related_word': 'Q58494516',
#   'related_word_label': 'wikilink'},
#  {'word': 'Q43297',
#   'word_label': 'Time',
#   'relation': 'P31',
#   'related_word': 'Q41298',
#   'related_word_label': 'magazine'},
#  {'word': 'Q43297',
#   'word_label': 'Time',
#   'relation': 'P31',
#   'related_word': 'Q847906',
#   'related_word_label': 'online magazine'},
#  {'word': 'Q43297',
#   'word_label': 'Time',
#   'relation': 'P31',
#   'related_word': 'Q1684600',
#   'related_word_label': 'news magazine'},
#  {'word': 'Q43297',
#   'word_label': 'Time',
#   'relation': 'P1889',
#   'related_word': 'Q50008',
#   'related_word_label': 'The Times'},
#  {'word': 'Q43297',
#   'word_label': 'Time',
#   'relation': 'P1889',
#   'related_word': 'Q124535786',
#   'related_word_label': 'Time Magazine'},
#  {'word': 'Q80071',
#   'word_label': 'symbol',
#   'relation': 'P279',
#   'related_word': 'Q1272626',
#   'related_word_label': 'representation'},
#  {'word': 'Q80071',
#   'word_label': 'symbol',
#   'relation': 'P279',
#   'related_word': 'Q3695082',
#   'related_word_label': 'sign'},
#  {'word': 'Q80071',
#   'word_label': 'symbol',
#   'relation': 'P361',
#   'related_word': 'Q2001982',
#   'related_word_label': 'notation'},
#  {'word': 'Q80071',
#   'word_label': 'symbol',
#   'relation': 'P460',
#   'related_word': 'Q3695082',
#   'related_word_label': 'sign'},
#  {'word': 'Q80071',
#   'word_label': 'symbol',
#   'relation': 'P460',
#   'related_word': 'Q11634359',
#   'related_word_label': '0411'},
#  {'word': 'Q107994',
#   'word_label': 'vector',
#   'relation': 'P279',
#   'related_word': 'Q7239',
#   'related_word_label': 'organism'},
#  {'word': 'Q107994',
#   'word_label': 'vector',
#   'relation': 'P279',
#   'related_word': 'Q11494956',
#   'related_word_label': 'source of infection'},
#  {'word': 'Q107994',
#   'word_label': 'vector',
#   'relation': 'P460',
#   'related_word': 'Q11385914',
#   'related_word_label': 'Q11385914'},
#  {'word': 'Q107994',
#   'word_label': 'vector',
#   'relation': 'P1269',
#   'related_word': 'Q133805',
#   'related_word_label': 'epidemiology'},
#  {'word': 'Q107994',
#   'word_label': 'vector',
#   'relation': 'P1889',
#   'related_word': 'Q427389',
#   'related_word_label': 'genetic vector'},
#  {'word': 'Q162668',
#   'word_label': 'visual perception',
#   'relation': 'P31',
#   'related_word': 'Q2996394',
#   'related_word_label': 'biological process'},
#  {'word': 'Q162668',
#   'word_label': 'visual perception',
#   'relation': 'P279',
#   'related_word': 'Q160402',
#   'related_word_label': 'perception'},
#  {'word': 'Q162668',
#   'word_label': 'visual perception',
#   'relation': 'P279',
#   'related_word': 'Q14859561',
#   'related_word_label': 'sensory perception of light stimulus'},
#  {'word': 'Q162668',
#   'word_label': 'visual perception',
#   'relation': 'P361',
#   'related_word': 'Q1051623',
#   'related_word_label': 'five wits'},
#  {'word': 'Q162668',
#   'word_label': 'visual perception',
#   'relation': 'P361',
#   'related_word': 'Q77468620',
#   'related_word_label': 'psychology terminology'},
#  {'word': 'Q162668',
#   'word_label': 'visual perception',
#   'relation': 'P460',
#   'related_word': 'Q760329',
#   'related_word_label': 'Q760329'},
#  ...]

# %%
# Convert to DataFrame and save to CSV
output_df = pd.DataFrame(store_results(all_results_ood))
output_df.to_csv('modality_relations_one_end.csv', index=False)
